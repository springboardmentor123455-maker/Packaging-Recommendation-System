# %%
import pandas as pd

df = pd.read_csv("materials_milestone1_final.csv")
df.head()
# Out:
#    id             material  weight  cost  co2_emission  durability  \
# 0   1   Recycled Cardboard   44.55  3.95         0.841           7
# 1   2  Corn Starch Polymer   42.85  4.91         0.702           1
# 2   3   Recycled Cardboard   38.48  4.22         0.931           8
# 3   4  Recycled Paperboard   10.84  1.34         0.837           8
# 4   5  Recycled Paperboard   20.44  3.93         1.054           1
#
#    recyclable  co2_impact_index  cost_efficiency_index  sustainability_score
# 0           0          0.561415               0.095386              0.408767
# 1           0          0.468625               0.000125              0.245883
# 2           0          0.621495               0.102892              0.418069
# 3           1          0.558745               0.350350              0.743169
# 4           1          0.703605               0.003209              0.451891

# %%
y_cost = df['cost']
y_co2  = df['co2_emission']

# %%
features = [
    'weight',
    'durability',
    'recyclable',
    'co2_impact_index',
    'cost_efficiency_index',
    'sustainability_score'
]

X = df[features]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_cost_train, y_cost_test = train_test_split(
    X, y_cost, test_size=0.2, random_state=42
)

_, _, y_co2_train, y_co2_test = train_test_split(
    X, y_co2, test_size=0.2, random_state=42
)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_cost = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

rf_cost.fit(X_train, y_cost_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_co2 = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

rf_co2.fit(X_train, y_co2_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Cost predictions
cost_pred = rf_cost.predict(X_test)

# CO2 predictions
co2_pred = rf_co2.predict(X_test)

def evaluate(y_true, y_pred, name):
    print(f"\n{name}")
    print("MAE :", mean_absolute_error(y_true, y_pred))
    print("RMSE:", np.sqrt(mean_squared_error(y_true, y_pred)))
    print("R2  :", r2_score(y_true, y_pred))

evaluate(y_cost_test, cost_pred, "Cost Prediction Model")
evaluate(y_co2_test, co2_pred, "CO2 Prediction Model")
# Out:
# Cost Prediction Model
# MAE : 0.11825599999999964
# RMSE: 0.166629735041498
# R2  : 0.984133558360042
#
# CO2 Prediction Model
# MAE : 0.0032603000000000883
# RMSE: 0.004262639909727405
# R2  : 0.9998849048470798

# %%
df['predicted_cost'] = rf_cost.predict(X)
df['predicted_co2']  = rf_co2.predict(X)

df['final_rank_score'] = (
    0.5 * (1 - df['predicted_co2']/df['predicted_co2'].max()) +
    0.5 * (1 - df['predicted_cost']/df['predicted_cost'].max())
)

df.sort_values(by='final_rank_score', ascending=False).head(10)
# Out:
#       id               material  weight  cost  co2_emission  durability  \
# 132  133  Biodegradable Plastic   36.04  0.86         0.099           6
# 351  352    Corn Starch Polymer    5.33  0.84         0.095           1
# 258  259               Aluminum   14.83  0.86         0.115           3
# 403  404          Bagasse Fiber   51.56  0.72         0.218           6
# 320  321          Bagasse Fiber   34.50  1.02         0.157           9
# 229  230                  Glass   59.01  1.42         0.066           7
# 62    63         PLA Bioplastic   24.60  0.87         0.230           4
# 118  119          Bagasse Fiber   52.91  0.55         0.313           7
# 435  436               Aluminum   37.17  1.03         0.216           5
# 206  207               Aluminum   16.08  1.09         0.184           3
#
#      recyclable  co2_impact_index  cost_efficiency_index  \
# 132           1          0.066088               0.411486
# 351           1          0.063418               0.060058
# 258           1          0.076769               0.199620
# 403           0          0.145527               0.493878
# 320           1          0.104806               0.523649
# 229           0          0.044059               0.287151
# 62            1          0.153538               0.266995
# 118           0          0.208945               0.760742
# 435           1          0.144192               0.282584
# 206           0          0.122830               0.154915
#
#      sustainability_score  predicted_cost  predicted_co2  final_rank_score
# 132              0.873565          0.8521        0.10311          0.878681
# 351              0.707966          0.9194        0.09884          0.873248
# 258              0.769292          0.9335        0.11190          0.867446
# 403              0.541789          0.7471        0.21762          0.851115
# 320              0.958077          0.9647        0.15720          0.849126
# 229              0.615710          1.3895        0.06697          0.835980
# 62               0.771918          0.8769        0.22611          0.835046
# 118              0.549755          0.6114        0.31089          0.833776
# 435              0.808990          0.9777        0.21659          0.827953
# 206              0.450868          1.1099        0.18531          0.824931
