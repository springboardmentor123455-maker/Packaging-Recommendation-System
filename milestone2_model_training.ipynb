# %%
import pandas as pd

df = pd.read_csv("materials_milestone1_final.csv")
df.head()
# Out:
#    id                              material  weight  cost  co2_emission  \
# 0   1      Leaf Husk Biopolymer Lightweight    14.9   5.9          0.42
# 1   2   Plant-Based Laminate Recycled Large    24.5   6.0          0.54
# 2   3  Recycled Plastic Mix HeavyDuty Small    13.4   8.2          0.09
# 3   4       Sugar Palm Fiber Consumer Small    14.9   5.2          0.38
# 4   5                 Rice Straw Pulp Blend    33.4   7.4          0.28
#
#    recyclable  durability  co2_impact_index  cost_efficiency_index  \
# 0           1           6          0.264984               0.228116
# 1           1           5          0.340694               0.159314
# 2           1           8          0.056782               0.212626
# 3           1           7          0.239748               0.351471
# 4           1           7          0.176656               0.201510
#
#    sustainability_score
# 0              0.774006
# 1              0.713722
# 2              0.917287
# 3              0.814101
# 4              0.839338

# %%
y_cost = df['cost']
y_co2  = df['co2_emission']

# %%
features = [
    'weight',
    'durability',
    'recyclable',
    'co2_impact_index',
    'cost_efficiency_index',
    'sustainability_score'
]

X = df[features]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_cost_train, y_cost_test = train_test_split(
    X, y_cost, test_size=0.2, random_state=42
)

_, _, y_co2_train, y_co2_test = train_test_split(
    X, y_co2, test_size=0.2, random_state=42
)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_cost = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

rf_cost.fit(X_train, y_cost_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_co2 = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

rf_co2.fit(X_train, y_co2_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Cost predictions
cost_pred = rf_cost.predict(X_test)

# CO2 predictions
co2_pred = rf_co2.predict(X_test)

def evaluate(y_true, y_pred, name):
    print(f"\n{name}")
    print("MAE :", mean_absolute_error(y_true, y_pred))
    print("RMSE:", np.sqrt(mean_squared_error(y_true, y_pred)))
    print("R2  :", r2_score(y_true, y_pred))

evaluate(y_cost_test, cost_pred, "Cost Prediction Model")
evaluate(y_co2_test, co2_pred, "CO2 Prediction Model")
# Out:
# Cost Prediction Model
# MAE : 0.13278499999999951
# RMSE: 0.2214545382239876
# R2  : 0.986887432831569
#
# CO2 Prediction Model
# MAE : 0.002561000000000048
# RMSE: 0.005731570465413539
# R2  : 0.9996839994017797

# %%
df['predicted_cost'] = rf_cost.predict(X)
df['predicted_co2']  = rf_co2.predict(X)

df['final_rank_score'] = (
    0.5 * (1 - df['predicted_co2']/df['predicted_co2'].max()) +
    0.5 * (1 - df['predicted_cost']/df['predicted_cost'].max())
)

df.sort_values(by='final_rank_score', ascending=False).head(10)
# Out:
#       id                             material   weight  cost  co2_emission  \
# 315  316    Recycled Jute Mix Composite Fiber  30.9000   2.7          0.10
# 273  274      Recycled Cotton Recycled Medium  13.3000   2.5          0.20
# 261  262     Recycled Jute Mix Consumer Sheet  25.2000   2.6          0.23
# 346  347     Recycled Aluminum Consumer Fiber  53.8375   3.1          0.17
# 383  384         Recycled Steel Recycled Pack  53.8375   3.2          0.16
# 51    52  Citrus Waste Polymer Recycled Large  16.4000   3.6          0.13
# 41    42   Recycled Fiber Foam Standard Small  20.0000   3.8          0.10
# 22    23       Paper-Pulp Mold Recycled Blend  22.9000   2.9          0.26
# 49    50       Hard Paper Shell Standard Pack  38.0000   3.3          0.24
# 484  485     Kenaf-Pulp Blend Standard Medium  18.1000   3.2          0.27
#
#      recyclable  durability  co2_impact_index  cost_efficiency_index  \
# 315           1           6          0.063091               0.679739
# 273           1           7          0.126183               0.896235
# 261           1           6          0.145110               0.711765
# 346           1           7          0.107256               0.693169
# 383           1           8          0.100946               0.783824
# 51            1           5          0.082019               0.367484
# 41            1           7          0.063091               0.537307
# 22            1           6          0.164038               0.622312
# 49            1           6          0.151420               0.528342
# 484           1           6          0.170347               0.549632
#
#      sustainability_score  predicted_cost  predicted_co2  final_rank_score
# 315              0.854763           2.750         0.1062          0.842908
# 273              0.859527           2.707         0.1983          0.815787
# 261              0.821956           2.660         0.2273          0.808751
# 346              0.867098           3.135         0.1664          0.806615
# 383              0.899621           3.249         0.1608          0.803259
# 51               0.817192           3.667         0.1232          0.796334
# 41               0.884763           3.895         0.1047          0.791923
# 22               0.814385           2.822         0.2602          0.791092
# 49               0.819432           3.317         0.2407          0.774997
# 484              0.811861           3.225         0.2703          0.769795
