# %%
#Imported important libraries

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#Loaded the dataset

df  = pd.read_csv('cleaned_materials.csv')
df.head
# Out:
# <bound method NDFrame.head of      Material_ID  Strength_MPa  Weight_Capacity_kg  Biodegradability_Score  \
# 0       MAT00001      0.024921            0.275033                 0.22375
# 1       MAT00002      0.093601            0.232596                 0.60250
# 2       MAT00003      0.809409            0.006366                 0.80625
# 3       MAT00004      0.358914            0.343943                 0.26500
# 4       MAT00005      0.885437            0.361625                 0.19250
# ...          ...           ...                 ...                     ...
# 9995    MAT09996      0.327605            0.856825                 0.57625
# 9996    MAT09997      0.815144            0.864706                 0.23750
# 9997    MAT09998      0.456985            0.560877                 0.23125
# 9998    MAT09999      0.822594            0.420531                 0.11250
# 9999    MAT10000      0.427472            0.774578                 0.07000
#
# ...

# %%
#Check dataset structure Verify columns & data types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 59 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Material_ID                          10000 non-null  object
#  1   Strength_MPa                         10000 non-null  float64
#  2   Weight_Capacity_kg                   10000 non-null  float64
#  3   Biodegradability_Score               10000 non-null  float64
#  4   CO2_Emission_Score_kg                10000 non-null  float64
#  5   Recyclability_Percentage             10000 non-null  float64
#  6   Source                               10000 non-null  object
#  7   Certification                        10000 non-null  object
#  8   Price_INR                            10000 non-null  float64
#  9   Material_Type_Bio-based Polymer      10000 non-null  bool
#  10  Material_Type_Biodegradable Plastic  10000 non-null  bool
# ...

# %%
#Select ML features

feature_cols = [
    "Strength_MPa",
    "Weight_Capacity_kg",
    "Biodegradability_Score",
    "Recyclability_Percentage",
    "CO2_Emission_Score_kg"
]

X = df[feature_cols]
X.head()
# Out:
#    Strength_MPa  Weight_Capacity_kg  Biodegradability_Score  \
# 0      0.024921            0.275033                 0.22375
# 1      0.093601            0.232596                 0.60250
# 2      0.809409            0.006366                 0.80625
# 3      0.358914            0.343943                 0.26500
# 4      0.885437            0.361625                 0.19250
#
#    Recyclability_Percentage  CO2_Emission_Score_kg
# 0                     0.677               0.736552
# 1                     0.716               0.561379
# 2                     0.340               0.697931
# 3                     0.459               0.043448
# 4                     0.661               0.069655

# %%
#Create target variable for price

y_cost = df["Price_INR"]
y_cost.head()
# Out:
# 0    0.892455
# 1    0.701542
# 2    0.155481
# 3    0.124844
# 4    0.773447
# Name: Price_INR, dtype: float64

# %%
#Generate target CO₂ Impact Prediction

y_co2 = df["CO2_Emission_Score_kg"]
y_co2.head()
# Out:
# 0    0.736552
# 1    0.561379
# 2    0.697931
# 3    0.043448
# 4    0.069655
# Name: CO2_Emission_Score_kg, dtype: float64

# %%
# Split the dataset into training and testing sets for cost prediction

X_train_cost, X_test_cost, y_train_cost, y_test_cost = train_test_split(X, y_cost, test_size=0.2, random_state=42)
print(X_train_cost.shape, X_test_cost.shape)
# Out:
# (8000, 5) (2000, 5)

# %%
# Split the dataset into training and testing sets for CO2 Emission Prediction

X_train_co2, X_test_co2, y_train_co2, y_test_co2 = train_test_split(X, y_co2, test_size=0.2, random_state=42)
print(X_train_co2.shape, X_test_co2.shape)
# Out:
# (8000, 5) (2000, 5)

# %%
#Scaling (Data Pipeline step) Normalize data for ML models

scaler = StandardScaler()

X_train_cost_scaled = scaler.fit_transform(X_train_cost)
X_test_cost_scaled = scaler.transform(X_test_cost)

X_train_co2_scaled = scaler.fit_transform(X_train_co2)
X_test_co2_scaled = scaler.transform(X_test_co2)

# %%
#verify the shapes of the scaled data

print("Cost model training data shape:", X_train_cost_scaled.shape)
print("CO2 model training data shape:", X_train_co2_scaled.shape)
# Out:
# Cost model training data shape: (8000, 5)
# CO2 model training data shape: (8000, 5)
